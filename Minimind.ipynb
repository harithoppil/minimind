# %%
# !git clone https://github.com/harithoppil/minimind.git
# Out:
# Cloning into 'minimind'...
# remote: Enumerating objects: 1830, done.
# remote: Counting objects: 100% (267/267), done.
# remote: Compressing objects: 100% (148/148), done.
# remote: Total 1830 (delta 188), reused 156 (delta 119), pack-reused 1563 (from 2)
# Receiving objects: 100% (1830/1830), 28.20 MiB | 40.85 MiB/s, done.
# Resolving deltas: 100% (1121/1121), done.

# %%
import os
if os.path.exists('minimind'):
    # %cd minimind
    # !git pull
    # %cd ..
else:
    print('The minimind directory does not exist. Please clone it first.')
# Out:
# /content/minimind
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (1/1), done.
# remote: Total 5 (delta 4), reused 5 (delta 4), pack-reused 0 (from 0)
# Unpacking objects: 100% (5/5), 800 bytes | 800.00 KiB/s, done.
# From https://github.com/harithoppil/minimind
#    445e03d..ec28d66  master     -> origin/master
# Updating 445e03d..ec28d66
# Fast-forward
#  trainer/train_full_sft.py | 19 +++++++++++++------
#  trainer/train_pretrain.py | 19 +++++++++++++------
#  2 files changed, 26 insertions(+), 12 deletions(-)
# /content

# %%
# !rm -rf minimind

# %%
# !pip install -r minimind/requirements.txt
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.5/96.5 kB 6.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.5/48.5 kB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 89.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 532.9/532.9 kB 45.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 156.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 154.9 MB/s eta 0:00:00
# ...

# %%
import wandb
wandb.login()
#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
# Out:
# /usr/local/lib/python3.12/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: (1) Create a W&B account
# wandb: (2) Use an existing W&B account
# wandb: (3) Don't visualize my results
# wandb: Enter your choice:
#  2
# wandb: You chose 'Use an existing W&B account'
# wandb: Logging into https://api.wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: Find your API key here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: harithoppil (harithoppil-personal) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# !sudo apt update
# !sudo apt install -y aria2
# Out:
# Get:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:2 https://cli.github.com/packages stable InRelease [3,917 B]
# Get:3 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Hit:4 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Get:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:9 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [24.6 kB]
# Get:10 https://cli.github.com/packages stable/main amd64 Packages [356 B]
# Get:11 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [2,328 kB]
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
import os

# 1. Create the dataset folder
os.makedirs("dataset", exist_ok=True)

# 2. Download "pretrain_hq_en.jsonl" -> save as "pretrain_hq.jsonl"
# !aria2c -x16 -o dataset/pretrain_hq.jsonl "https://huggingface.co/datasets/harithoppil/minimind_dataset/resolve/main/pretrain_hq_en.jsonl?download=true"

# 3. Download "sft_mini_512_en.jsonl" -> save as "sft_mini_512.jsonl"
#!aria2c -x16 -o dataset/sft_mini_512.jsonl "https://huggingface.co/datasets/harithoppil/minimind_dataset/resolve/main/sft_mini_512_en.jsonl?download=true"

# !aria2c -x16 -o dataset/sft_1024.jsonl "https://huggingface.co/datasets/harithoppil/minimind_dataset/resolve/main/sft_1024_en.jsonl?download=true"

print("✅ Files downloaded and renamed successfully!")
print("📂 Your dataset folder now contains:")
# !ls -lh dataset/
# Out:
# 01/31 21:12:51 [NOTICE] Downloading 1 item(s)
#
# ...

# %%
# !mkdir

# %%
import os
cpu_count = os.cpu_count()
print(f"🧠 Total CPU Cores Available: {cpu_count}")

# Recommended setting based on your hardware
recommended_workers = min(cpu_count, 16)
print(f"✅ You should set --num_workers {recommended_workers}")
# Out:
# 🧠 Total CPU Cores Available: 12
# ✅ You should set --num_workers 12

# %%
from datetime import datetime
from zoneinfo import ZoneInfo

# Get the current time in IST (Asia/Kolkata is the IANA name for IST)
ist_time = datetime.now(ZoneInfo("Asia/Kolkata"))

# Print the time in the default format
print(f"PreTraining Start time: {ist_time}")
# Out:
# PreTraining Start time: 2026-01-31 17:40:32.769295+05:30

# %% [markdown]
# 8:50pm start - logs 15:20 ( 5.60pm

# %%
import os
# This runs the training using exactly the number of cores you have (max 16)
# !python minimind/trainer/train_pretrain.py \
--batch_size 124 \
--num_workers 12  \
--use_wandb  \
--accumulation_steps 1 \
--hidden_size 512  \
--max_seq_len 512  \
--use_compile 1  \
--num_hidden_layers 6  \
--save_weight "pretrain_minimind2_104m"  \
--wandb_project "MoeMLPattentionModel-Pretrain" \
--use_tempmodel 1
# Out:
# 2026-01-31 12:14:26.904243: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-31 12:14:26.923352: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769861666.945022   14390 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769861666.951668   14390 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !cp drive/MyDrive/models/pretrain_minimind2_104m_512_resume.pth /content/checkpoints/

# %%
import os
# This runs the training using exactly the number of cores you have (max 16)
# !python minimind/trainer/train_pretrain.py \
--batch_size 124 \
--num_workers 12  \
--use_wandb  \
--accumulation_steps 1 \
--hidden_size 512  \
--max_seq_len 512  \
--use_compile 1  \
--num_hidden_layers 6  \
--save_weight "pretrain_minimind2_104m"  \
--wandb_project "MoeMLPattentionModel-Pretrain" \
--epochs 2 \
--from_resume 1 \
--use_tempmodel 1
# Out:
# 2026-01-31 21:22:35.885680: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-31 21:22:35.903938: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769894555.925841   11201 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769894555.932527   11201 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
import os
# This runs the training using exactly the number of cores you have (max 16)
# !python minimind/trainer/train_pretrain.py \
--batch_size 172 \
--num_workers 12  \
--use_wandb  \
--accumulation_steps 1 \
--hidden_size 768  \
--max_seq_len 512  \
--use_compile 1  \
--num_hidden_layers 16  \
--save_weight "pretrain_minimind2_104m"  \
--wandb_project "MiniMind2-104M"
# Out:
# 2026-01-30 09:01:44.088123: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-30 09:01:44.106066: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769763704.128490   10193 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769763704.135168   10193 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from datetime import datetime
from zoneinfo import ZoneInfo

# Get the current time in IST (Asia/Kolkata is the IANA name for IST)
ist_time = datetime.now(ZoneInfo("Asia/Kolkata"))

# Print the time in the default format
print(f"PreTraining finished time: {ist_time}")
# Out:
# PreTraining finished time: 2026-02-01 04:47:28.467717+05:30

# %%
# !python minimind/trainer/train_full_sft.py \
--batch_size 124 \
--num_workers 12  \
--use_wandb  \
--accumulation_steps 8 \
--hidden_size 512  \
--max_seq_len 512  \
--use_compile 1  \
--num_hidden_layers 6  \
--from_weight "pretrain_minimind2_104m" \
--save_weight "sft_minimind2_104m" \
--wandb_project "MoeMLPattentionModel-SFT" \
--data_path "/content/dataset/sft_1024.jsonl" \
--use_tempmodel 1
# Out:
# 2026-01-31 23:17:43.851338: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-31 23:17:43.869314: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1769901463.890907   42285 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1769901463.897470   42285 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
from datetime import datetime
from zoneinfo import ZoneInfo

# Get the current time in IST (Asia/Kolkata is the IANA name for IST)
ist_time = datetime.now(ZoneInfo("Asia/Kolkata"))

# Print the time in the default format
print(f"SFT Training finished time: {ist_time}")
# Out:
# SFT Training finished time: 2026-01-30 17:00:56.455749+05:30

# %%
# ============================================================================
# STEP 1: Install google-cloud-storage
# ============================================================================
print("Installing google-cloud-storage...")
# !pip install google-cloud-storage -q

# ============================================================================
# STEP 2: Zip Folders & Upload
# ============================================================================

import os
import zipfile
from pathlib import Path
from google.cloud import storage

# --- Configuration ---
BUCKET_NAME = "checkpoints-torch"
GCS_FOLDER = "sentanceformer"
# The name of the resulting zip file
ZIP_FILENAME = "minimind_v2_pretrain_sft_1024.zip"

# List of folders you want to zip (Absolute Paths)
FOLDERS_TO_ZIP = [
    "/content/out",
    "/checkpoint"
]

# Destination path in the bucket
DESTINATION_BLOB_NAME = f"{GCS_FOLDER}/{ZIP_FILENAME}"

# ----------------------------------------------------------------------------
# SERVICE ACCOUNT KEY
# ----------------------------------------------------------------------------
SERVICE_ACCOUNT_KEY = {
    "type": "service_account",
    "project_id": "authentic-host-465814-d0",
    "private_key_id": "321e8506803857df9b7f30bf94e0572d8ce05d24",
    "private_key": "-----BEGIN PRIVATE KEY-----\\n-----END PRIVATE KEY-----\n",
    "client_email": "revolyzz@authentic-host-465814-d0.iam.gserviceaccount.com",
    "client_id": "101285863922371423742",
    "auth_uri": "https://accounts.google.com/o/oauth2/auth",
    "token_uri": "https://oauth2.googleapis.com/token",
    "auth_provider_x509_cert_url": "https://www.googleapis.com/oauth2/v1/certs",
    "client_x509_cert_url": "https://www.googleapis.com/robot/v1/metadata/x509/revolyzz%40authentic-host-465814-d0.iam.gserviceaccount.com",
    "universe_domain": "googleapis.com"
}

def create_zip_archive(output_filename, source_folders):
    """
    Zips multiple folders into one archive without moving/copying original files.
    Preserves the folder name in the zip structure (e.g., /content/out/file -> out/file).
    """
    print(f"📦 Zipping folders into {output_filename}...")

    with zipfile.ZipFile(output_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for folder in source_folders:
            folder_path = Path(folder)

            if not folder_path.exists():
                print(f"⚠️ Warning: Folder not found: {folder}")
                continue

            print(f"   -> Adding: {folder}")
            # Walk through the directory
            for root, dirs, files in os.walk(folder_path):
                for file in files:
                    file_path = os.path.join(root, file)
                    # arcname is the name stored inside the zip
                    # We use relative path from the folder's parent to keep the folder name
                    arcname = os.path.relpath(file_path, start=folder_path.parent)
                    zipf.write(file_path, arcname)

    print(f"✓ Zip created. Size: {os.path.getsize(output_filename) / 1e6:.2f} MB")

# ----------------------------------------------------------------------------
# EXECUTION
# ----------------------------------------------------------------------------
print("\n" + "="*70)
print("STARTING ZIP AND UPLOAD PROCESS")
print("="*70)

try:
    # 1. Create the Zip File
    create_zip_archive(ZIP_FILENAME, FOLDERS_TO_ZIP)

    # 2. Check if zip exists
    local_zip_path = Path(ZIP_FILENAME)
    if not local_zip_path.exists():
        raise FileNotFoundError("Zip file creation failed.")

    # 3. Authenticate
    print("\nAuthenticating with GCS...")
    client = storage.Client.from_service_account_info(SERVICE_ACCOUNT_KEY)
    bucket = client.bucket(BUCKET_NAME)
    blob = bucket.blob(DESTINATION_BLOB_NAME)

    # 4. Upload
    print(f"Uploading to: gs://{BUCKET_NAME}/{DESTINATION_BLOB_NAME}")
    print("-" * 30)

    blob.upload_from_filename(str(local_zip_path))

    print("\n" + "="*70)
    print("✓ UPLOAD COMPLETE")
    print("="*70)
    print(f"File accessible at: gs://{BUCKET_NAME}/{DESTINATION_BLOB_NAME}")

except Exception as e:
    print(f"\n❌ An error occurred: {e}")
# Out:
# Installing google-cloud-storage...
#
# ...
# STARTING ZIP AND UPLOAD PROCESS
# ...
# 📦 Zipping folders into minimind_v2_pretrain_sft_1024.zip...
#    -> Adding: /content/out
# ⚠️ Warning: Folder not found: /checkpoint
# ✓ Zip created. Size: 2312.65 MB
#
# Authenticating with GCS...
# Uploading to: gs://checkpoints-torch/sentanceformer/minimind_v2_pretrain_sft_1024.zip
# ------------------------------
#
# ...
# ✓ UPLOAD COMPLETE
# ...
# File accessible at: gs://checkpoints-torch/sentanceformer/minimind_v2_pretrain_sft_1024.zip

# %%
import sys
import os
import torch
from transformers import AutoTokenizer

# --- CONFIGURATION ---
# 1. Path to your Repo (Assumes running from repo root or /content)
REPO_DIR = os.path.abspath("minimind") if os.path.exists("minimind") else os.path.abspath(".")

# 2. Path to the FINAL weights (Try /out first)
MODEL_PATH = os.path.join(REPO_DIR, "checkpoints", "sft_minimind2_104m_768.pth")
if not os.path.exists(MODEL_PATH):
    # Fallback to current directory or ../out
    MODEL_PATH = "/content/checkpoints/pretrain_minimind2_104m_512.pth"

# 3. Device
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

# ---------------------
if REPO_DIR not in sys.path: sys.path.append(REPO_DIR)
try:
    from model.model_minimind import MiniMindForCausalLM, MiniMindConfig
except ImportError:
    sys.path.append(".")
    from model.model_minimind import MiniMindForCausalLM, MiniMindConfig

def run_chat():
    print(f"🔧 Loading GPT-2 Tokenizer (and patching)...")
    # ALWAYS load GPT-2 base to ensure vocab matches your checkpoint
    tokenizer = AutoTokenizer.from_pretrained("gpt2")

    # Apply the EXACT same patches as training
    special_tokens_dict = {
        "bos_token": "<|im_start|>",
        "eos_token": "<|im_end|>",
        "pad_token": "<|endoftext|>",
        "additional_special_tokens": ["<|im_start|>", "<|im_end|>"]
    }
    tokenizer.add_special_tokens(special_tokens_dict)

    # ChatML Template
    tokenizer.chat_template = (
        "{% for message in messages %}"
        "{{'<|im_start|>' + message['role'] + '\n' + message['content'] + '<|im_end|>' + '\n'}}"
        "{% endfor %}"
        "{% if add_generation_prompt %}"
        "{{ '<|im_start|>assistant\n' }}"
        "{% endif %}"
    )

    vocab_size = len(tokenizer) # Should be 50259
    print(f"   Vocab Size: {vocab_size}")

    print(f"⚖️  Loading Weights from {MODEL_PATH} ...")
    config = MiniMindConfig(
        hidden_size=512,
        num_hidden_layers=6,
        vocab_size=vocab_size,
        use_moe=False
    )
    model = MiniMindForCausalLM(config).to(DEVICE)

    # Resize embeddings to match 50259
    model.model.embed_tokens = torch.nn.Embedding(vocab_size, 512).to(DEVICE)
    model.lm_head = torch.nn.Linear(512, vocab_size, bias=False).to(DEVICE)

    if os.path.exists(MODEL_PATH):
        # strict=False is safer for manual resizing
        model.load_state_dict(torch.load(MODEL_PATH, map_location=DEVICE), strict=False)
        print("✅ Model loaded successfully!")
    else:
        print(f"❌ Error: File not found: {MODEL_PATH}")
        return

    model.eval()

    # --- SANITY CHECK ---
    print("\n🔎 Running Sanity Check...")
    # Pretrained models might not follow instructions well, so we test completion
    test_prompt = "hi"
    print(f"INPUT: {test_prompt}")

    inputs = tokenizer(test_prompt, return_tensors="pt").to(DEVICE)

    with torch.no_grad():
        out = model.generate(
            **inputs,
            max_new_tokens=512,
            pad_token_id=tokenizer.eos_token_id,
            eos_token_id=tokenizer.eos_token_id,
            do_sample=True,
            temperature=0.7
        )

    response = tokenizer.decode(out[0], skip_special_tokens=True)
    print(f"OUTPUT: {response}\n")
    print("-" * 40)

    # Interactive Loop
    while True:
        prompt = input("👤 User (type 'exit' to quit): ")
        if prompt.lower() in ['exit', 'quit']: break

        # Note: Pretrained base models are NOT chat models.
        # Using raw prompt completion usually works better than chat templates until SFT.
        # But we use the chat template here since that's your goal.
        messages = [{"role": "user", "content": prompt}]
        text = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)

        inputs = tokenizer(text, return_tensors="pt").to(DEVICE)

        with torch.no_grad():
            out = model.generate(
                **inputs,
                max_new_tokens=512,
                pad_token_id=tokenizer.eos_token_id,
                eos_token_id=tokenizer.eos_token_id,
                temperature=1,
                top_p=0.9,
                do_sample=True
            )
        response = tokenizer.decode(out[0][inputs.input_ids.shape[1]:], skip_special_tokens=True)
        print(f"🤖 MiniMind: {response}")

if __name__ == "__main__":
    run_chat()
# Out:
# 🔧 Loading GPT-2 Tokenizer (and patching)...
#    Vocab Size: 50259
# ⚖️  Loading Weights from /content/checkpoints/pretrain_minimind2_104m_512.pth ...
# ✅ Model loaded successfully!
#
# 🔎 Running Sanity Check...
# INPUT: hi
# ...

# %%
"""
TempModel Inference Script

Standalone inference script for TempModel.
Can be run directly or copied into a notebook cell.

Usage:
    python inference.py
"""

import sys
import os
import torch
from transformers import AutoTokenizer

# --- CONFIGURATION ---
REPO_DIR = os.path.abspath("minimind") if os.path.exists("minimind") else os.path.abspath(".")

MODEL_PATH = os.path.join(REPO_DIR, "checkpoints", "tempmodel.pth")
if not os.path.exists(MODEL_PATH):
    MODEL_PATH = os.path.join(REPO_DIR, "out", "tempmodel.pth")
if not os.path.exists(MODEL_PATH):
    MODEL_PATH = "/content/out/pretrain_minimind2_104m_512.pth"

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"

MODEL_CONFIG = {
    "hidden_size": 512,
    "num_hidden_layers": 6,
    "num_attention_heads": 12,
    "num_key_value_heads": 4,
    "n_routed_experts": 4,
    "n_shared_experts": 1,
    "num_experts_per_tok": 2,
}

if REPO_DIR not in sys.path:
    sys.path.append(REPO_DIR)

try:
    from model.tempmodel import TempModelForCausalLM, TempModelConfig
except ImportError:
    sys.path.append(".")
    from model.tempmodel import TempModelForCausalLM, TempModelConfig


def load_model(model_path, device, vocab_size):
    """Load TempModel from checkpoint."""
    print(f"Loading Weights from {model_path} ...")

    config = TempModelConfig(
        hidden_size=MODEL_CONFIG["hidden_size"],
        num_hidden_layers=MODEL_CONFIG["num_hidden_layers"],
        num_attention_heads=MODEL_CONFIG["num_attention_heads"],
        num_key_value_heads=MODEL_CONFIG["num_key_value_heads"],
        n_routed_experts=MODEL_CONFIG["n_routed_experts"],
        n_shared_experts=MODEL_CONFIG["n_shared_experts"],
        num_experts_per_tok=MODEL_CONFIG["num_experts_per_tok"],
        vocab_size=vocab_size,
    )

    model = TempModelForCausalLM(config).to(device)

    if model.model.embed_tokens.num_embeddings != vocab_size:
        model.model.embed_tokens = torch.nn.Embedding(vocab_size, MODEL_CONFIG["hidden_size"]).to(device)
        model.lm_head = torch.nn.Linear(MODEL_CONFIG["hidden_size"], vocab_size, bias=False).to(device)
        model.model.embed_tokens.weight = model.lm_head.weight

    if os.path.exists(model_path):
        model.load_state_dict(torch.load(model_path, map_location=device), strict=False)
        print("Model loaded successfully!")
    else:
        print(f"No checkpoint found at {model_path}")
        print("Running with randomly initialized weights (for testing)")

    return model


def run_chat():
    print("=" * 50)
    print("TempModel Inference")
    print("=" * 50)

    print("\nLoading GPT-2 Tokenizer...")
    tokenizer = AutoTokenizer.from_pretrained("gpt2")

    # Apply the same patches as training
    IM_START = "\u003c|im_start|\u003e"
    IM_END = "\u003c|im_end|\u003e"
    EOT = "\u003c|endoftext|\u003e"

    special_tokens_dict = {
        "bos_token": IM_START,
        "eos_token": IM_END,
        "pad_token": EOT,
        "additional_special_tokens": [IM_START, IM_END]
    }
    tokenizer.add_special_tokens(special_tokens_dict)

    # ChatML Template
    tokenizer.chat_template = (
        "{% for message in messages %}"
        "{{'" + IM_START + "' + message['role'] + '\\n' + message['content'] + '" + IM_END + "' + '\\n'}}"
        "{% endfor %}"
        "{% if add_generation_prompt %}"
        "{{ '" + IM_START + "assistant\\n' }}"
        "{% endif %}"
    )

    vocab_size = len(tokenizer)
    print(f"   Vocab Size: {vocab_size}")

    model = load_model(MODEL_PATH, DEVICE, vocab_size)
    model.eval()

    # --- SANITY CHECK ---
    print("\nRunning Sanity Check...")
    test_prompt = "hi"
    print(f"INPUT: {test_prompt}")

    inputs = tokenizer(test_prompt, return_tensors="pt").to(DEVICE)

    with torch.no_grad():
        out = model.generate(
            **inputs,
            max_new_tokens=64,
            pad_token_id=tokenizer.eos_token_id,
            eos_token_id=tokenizer.eos_token_id,
            do_sample=True,
            temperature=0.7
        )

    response = tokenizer.decode(out[0], skip_special_tokens=True)
    print(f"OUTPUT: {response}\n")
    print("-" * 40)

    # Interactive Loop
    while True:
        prompt = input("User (type 'exit' to quit): ")
        if prompt.lower() in ["exit", "quit"]:
            break

        messages = [{"role": "user", "content": prompt}]
        text = tokenizer.apply_chat_template(messages, tokenize=False, add_generation_prompt=True)

        inputs = tokenizer(text, return_tensors="pt").to(DEVICE)

        with torch.no_grad():
            out = model.generate(
                **inputs,
                max_new_tokens=512,
                pad_token_id=tokenizer.eos_token_id,
                eos_token_id=tokenizer.eos_token_id,
                temperature=1.0,
                top_p=0.9,
                do_sample=True
            )
        response = tokenizer.decode(out[0][inputs.input_ids.shape[1]:], skip_special_tokens=True)
        print(f"TempModel: {response}")


if __name__ == "__main__":
    run_chat()
# Out:
# ...
# TempModel Inference
# ...
#
# Loading GPT-2 Tokenizer...
#    Vocab Size: 50259
# Loading Weights from /content/out/pretrain_minimind2_104m_512.pth ...
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# /tmp/ipython-input-3573702791.py in <cell line: 0>()
#     161
#     162 if __name__ == "__main__":
# --> 163     run_chat()
#
# /tmp/ipython-input-3573702791.py in run_chat()
#     111     print(f"   Vocab Size: {vocab_size}")
#     112
# --> 113     model = load_model(MODEL_PATH, DEVICE, vocab_size)
#     114     model.eval()
#     115
#
# /tmp/ipython-input-3573702791.py in load_model(model_path, device, vocab_size)
#      68
#      69     if os.path.exists(model_path):
# ---> 70         model.load_state_dict(torch.load(model_path, map_location=device), strict=False)
#      71         print("Model loaded successfully!")
#      72     else:
#
# ...
